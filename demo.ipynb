# %%
import requests
import pandas as pd
import numpy as np
from urllib.request import urlopen, Request
from urllib.parse import urlencode
from bs4 import BeautifulSoup
import re

# %%
# Out:
# month                                            sector  yoy_chng  2y_chng  \
# 0                                   Employment Services      14.4     12.9
# 1                                           Information       9.5      3.4
# 2                     Health Care and Social Assistance       5.2      1.2
# 3      Professional, Scientific, and Technical Services       7.1      0.9
# 4                        Transportation and Warehousing      13.3     -3.8
# 5                               Administrative Services      10.1     -3.0
# 6                                            Government       1.2     -3.5
# 7                                 Finance and Insurance       0.6     -2.2
# 8                                           Real Estate       1.7     -7.0
# 9                                  Educational Services       1.2     -5.3
# 10                                            Utilities      -1.0     -4.9
# 11              Management of Companies and Enterprises       4.5     -5.2
# 12                                      Wholesale Trade       5.1     -7.5
# 13                                         Retail Trade       5.1    -10.6
# 14                                         Construction      -2.0    -11.6
# 15                                        Manufacturing       7.3    -11.2
# 16                      Accommodation and Food Services      45.5    -13.8
# 17                  Arts, Entertainment, and Recreation      52.2    -18.3
#
# month  3y_chng
# 0         14.0
# 1          7.4
# 2          5.1
# 3          1.9
# 4          0.2
# 5         -1.7
# 6         -1.8
# 7         -1.9
# 8         -6.5
# 9         -6.9
# 10        -8.3
# 11        -9.7
# 12       -10.0
# 13       -12.9
# 14       -13.3
# 15       -16.8
# 16       -19.0
# 17       -19.8
